# %% [markdown]
# <a href="https://colab.research.google.com/github/RohanCoderiiitb/TinyML-Harvard/blob/main/FashionMNIST_Using_DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
dataset = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (val_images, val_labels) = dataset.load_data()
plt.figure(figsize=(8,6))
for i in range(10):
  plt.subplot(1, 10, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(training_images[i], cmap='gray')
  plt.title(training_labels[i])
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
training_images = training_images/255.0
val_images = val_images/255.0
layer1 = tf.keras.layers.Dense(units=20, activation=tf.nn.relu)
layer2 = tf.keras.layers.Dense(units=10, activation=tf.nn.softmax)
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)),
                                    layer1,
                                    layer2])
model.compile(optimizer = tf.keras.optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(training_images, training_labels, epochs=20, validation_data=(val_images, val_labels))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7222 - loss: 0.8061 - val_accuracy: 0.8234 - val_loss: 0.5105
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8437 - loss: 0.4470 - val_accuracy: 0.8389 - val_loss: 0.4568
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8590 - loss: 0.4048 - val_accuracy: 0.8521 - val_loss: 0.4265
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8640 - loss: 0.3860 - val_accuracy: 0.8522 - val_loss: 0.4166
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8682 - loss: 0.3690 - val_accuracy: 0.8612 - val_loss: 0.4109
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8743 - loss: 0.3580 - val_accuracy: 0.8540 - val_loss: 0.4114
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8750 - loss: 0.3573 - val_accuracy: 0.8582 - val_loss: 0.4087
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8807 - loss: 0.3401 - val_accuracy: 0.8608 - val_loss: 0.3968
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8810 - loss: 0.3349 - val_accuracy: 0.8559 - val_loss: 0.4071
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8840 - loss: 0.3254 - val_accuracy: 0.8481 - val_loss: 0.4324
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8808 - loss: 0.3309 - val_accuracy: 0.8606 - val_loss: 0.3962
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8838 - loss: 0.3244 - val_accuracy: 0.8604 - val_loss: 0.3890
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8850 - loss: 0.3169 - val_accuracy: 0.8574 - val_loss: 0.4068
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8863 - loss: 0.3127 - val_accuracy: 0.8559 - val_loss: 0.4065
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8874 - loss: 0.3144 - val_accuracy: 0.8654 - val_loss: 0.3860
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8908 - loss: 0.3016 - val_accuracy: 0.8644 - val_loss: 0.3812
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8880 - loss: 0.3108 - val_accuracy: 0.8668 - val_loss: 0.3869
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8905 - loss: 0.3002 - val_accuracy: 0.8632 - val_loss: 0.3843
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8939 - loss: 0.2934 - val_accuracy: 0.8657 - val_loss: 0.3879
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8921 - loss: 0.2997 - val_accuracy: 0.8640 - val_loss: 0.3992

# %%
for i in range(10):
  plt.subplot(1, 10, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(val_images[i], cmap='gray')
  plt.title(val_labels[i])
plt.show()

# %%
model.evaluate(val_images, val_labels)
classifications = model.predict(val_images)
print(classifications[8])
print(val_labels[8])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8640 - loss: 0.3943
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# [1.1293688e-04 2.3576673e-05 5.4529282e-05 2.7088248e-04 6.1969342e-07
#  9.9776107e-01 2.2334511e-05 1.6828548e-03 7.1070972e-05 7.1679840e-09]
# 5
